# %%
# Project: Do fuel price changes affect political support?

# Edward Natusch - Data Science Project - University of Bristol 

# In this notebook, I will scrape UK Conservative Party polls from Savanta Comres, using Beautiful Soup.

# I will then clean this data using pandas and create monthly averages for conservative voting intention (as the polls are published irregularly).

# I will then download the 'CPIH INDEX: Liquid fuels, vehicle fuels & lubricants' dataset from the Office for National Statistics API.

# I will the merge the data sets, creating a CSV file with the conservative polling data and the CPIH Fuel Price Index for each available month.

# I will then visualise this data in vega-lite. The visualisation can be found on my project page at https://edward-natusch.github.io/project.html.

# The Westminster Voting Intention Polls from Savanta Comres and their methodology can be found here: https://comresglobal.com/poll-category/voting-intention/.

# The CPIH INDEX: Liquid fuels, vehicle fuels & lubricants dataset (produced monthly) and its methodology can be found here: https://www.ons.gov.uk/economy/inflationandpriceindices/timeseries/l5jl/mm23.

# %%
# Importing the required packages 

import numpy as np

from urllib.request import Request, urlopen

import pandas as pd

import requests

from bs4 import BeautifulSoup

import os

# %%
# Using beautiful soup to read the html data from comresglobal

url = 'https://comresglobal.com/poll-category/voting-intention/'

request = Request(url , headers ={'User-Agent':'Mozilla/5.0'})

html = urlopen(request).read()

soup = BeautifulSoup(html, 'html.parser')

# Creating an array 'links' to store the links found in the html data 

links = []

for link in soup.find_all('a'):
   links.append(link.get('href'))

# Creating an array 'VotingIntentionLinks' to store all the links, which include Westminster Voting Intention data

VotingIntentionLinks= []

for i in range(0,len(links)):
  if '/westminster-voting-intention-' in links[i]:
    VotingIntentionLinks.append(links[i])
    print(links[i])

# Creating two arrays 'Polls' and 'Text' to hold 

Polls = []

Text = []

# Looping through all the Westminster Voting Intention links and storing the text data in the array 'Polls'

for i in range(0,len(VotingIntentionLinks)):
  url = (VotingIntentionLinks[i])
  request = Request(url , headers ={'User-Agent':'Mozilla/5.0'})
  html = urlopen(request).read()
  soup = BeautifulSoup(html, 'html.parser')
  soup_li = soup.find_all("div", {"class": "col-md-7"})
  Polls.append(soup_li[0].text)
  print(soup_li[0].text)
# Out:
# https://comresglobal.com/polls/westminster-voting-intention-daily-express-17-december/
# https://comresglobal.com/polls/westminster-voting-intention-6-october/
# https://comresglobal.com/polls/westminster-voting-intention-7-december/
# https://comresglobal.com/polls/westminster-voting-intention-daily-mail-12-november/
# https://comresglobal.com/polls/westminster-voting-intention-9th-november-2021/
# https://comresglobal.com/polls/westminster-voting-intention-4th-november-2021/
# https://comresglobal.com/polls/westminster-voting-intention-27th-october-2021/
# https://comresglobal.com/polls/westminster-voting-intention-14th-october-2021/
# https://comresglobal.com/polls/westminster-voting-intention-15th-september-2021/
# https://comresglobal.com/polls/westminster-voting-intention-19th-august-2021/
# https://comresglobal.com/polls/westminster-voting-intention-25th-august-2021/
# https://comresglobal.com/polls/westminster-voting-intention-2nd-september-2021/
# https://comresglobal.com/polls/westminster-voting-intention-12th-august-2021/
# https://comresglobal.com/polls/westminster-voting-intention-3rd-aug-2021/
# https://comresglobal.com/polls/westminster-voting-intention-28th-july-2021/
# https://comresglobal.com/polls/westminster-voting-intention-14-july/
# https://comresglobal.com/polls/westminster-voting-intention-6th-july-2021/
# https://comresglobal.com/polls/westminster-voting-intention-29th-june-2021/
# https://comresglobal.com/polls/westminster-voting-intention-22nd-june-2021/
# https://comresglobal.com/polls/westminster-voting-intention-9th-june-2021/
# https://comresglobal.com/polls/westminster-voting-intention-and-government-pandemic-priority-polling-3rd-june-2021/
# https://comresglobal.com/polls/westminster-voting-intention-27th-may-2021/
# https://comresglobal.com/polls/westminster-voting-intention-11th-april-2021/
# https://comresglobal.com/polls/westminster-voting-intention-28th-april-2021/
# https://comresglobal.com/polls/westminster-voting-intention-14th-april-2021/
# https://comresglobal.com/polls/westminster-voting-intention-6th-april-2021/
# https://comresglobal.com/polls/westminster-voting-intention-26th-march-2021/
# https://comresglobal.com/polls/westminster-voting-intention-10th-march-2021/
# https://comresglobal.com/polls/westminster-voting-intention-2nd-march-2021/
# https://comresglobal.com/polls/westminster-voting-intention-24th-feb/
# https://comresglobal.com/polls/westminster-voting-intention-11-feb/
# https://comresglobal.com/polls/westminster-voting-intention-3-feb/
# https://comresglobal.com/polls/westminster-voting-intention-29-jan/
# https://comresglobal.com/polls/westminster-voting-intention-22-jan/
# https://comresglobal.com/polls/westminster-voting-intention-12-jan/
# https://comresglobal.com/polls/westminster-voting-intention-daily-express-1-jan/
# https://comresglobal.com/polls/westminster-voting-intention-2-december/
# https://comresglobal.com/polls/westminster-voting-intention-14th-oct/
#
#
# Westminster Voting Intention - Daily Express, 17 December
# Westminster Voting Intention
#
# Con 34 (+1)
# Lab 38 (-1)
# LDM 10 (+1)
# SNP 5 (-)
# Grn 4 (-)
# Other 9 (-)
#
# 2,139 UK adults, 16 Dec
#
# (Changes from 9-10 Dec)
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 17/12/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Daily Express
#
#
# Methodology
# Savanta ComRes interviewed 2,139 UK adults aged 18+ online on 16 December 2021. Data were weighted to be representative of all UK adults by age, sex, region, and SEG. Voting intention is also weighted by past vote recall (2019 and 2016) and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# P019622_Final_20211217_v1_Private (0.18MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 6 October
# NEW Westminster Voting Intention
#
# Con 40 (=)
# Lab 35 (=)
# LDM 9 (=)
# Grn 4 (-1)
# SNP 5 (+1)
# Other 8 (+1)
#
# 1-3 Oct, 2,095 UK adults
#
# (*Changes from 17-19 Sept)
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 6/10/2021
#
#
# Categories
#
# Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,095 UK adults aged 18+ online from 1-3 October 2021. Data were weighted to be representative of all UK adults by age, sex, region, and SEG. Voting intention is also weighted by past vote recall (2019 and 2016) and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20211006_03_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 7 December
# NEW Westminster Voting Intention
#
# Con 38 (+1)
# Lab 37 (=)
# LDM 9 (+1)
# Grn 5 (=)
# SNP 4 (-1)
# Other 7 (-2)
#
# 2,232 UK adults, 3-5 Dec
#
# (Changes from 26-28 Nov)
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 07/12/2021
#
#
# Categories
#
# Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,232 UK adults aged 18+ online from 3-5 December 2021. Data were weighted to be representative of all UK adults by age, sex, region, and SEG. Voting intention is also weighted by past vote recall (2019 and 2016) and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - Daily Mail, 12 November
# On behalf of the Daily Mail
#
# Lab 40 (+5)
# Con 34 (-4)
# LDM 10 (=)
# SNP 5 (=)
# Grn 5 (+1)
# Other 7 (-2)
#
# 2,019 UK adults, 11-12 Nov
#
# (Changes from 5-7 Nov)
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 12/11/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Daily Mail
#
#
# Methodology
# Savanta ComRes interviewed 2,019 UK adults aged 18+ online from 11-12th November 2021. Data were weighted to be representative of all UK adults by age, sex, region, and SEG. Voting intention was also weighted by past vote recall (2019 and 2016) and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# P018868_Final_weight_20211112_v1_Private (0.15MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 9th November 2021
# Westminster Voting Intention, fieldwork 5-7 November 2021
#
#
#
# CON: 38% (-2)
# LAB: 35% (=)
# LDM: 10% (+1)
# SNP: 5% (=)
# GRN: 4% (=)
#
# 5-7 Nov. Changes w/ 29-31 Oct
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 09/11/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,231 UK adults online from 5-7 November 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# Westminster VI 5-7 Nov 2021 (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 4th November 2021
# Westminster Voting Intention, fieldwork 29-31 October 2021
#
#
#
# Con 40 (+3)
# Lab 35 (=)
# LDM 9 (+1)
# SNP 5 (=)
# Grn 4 (-3)
# Other 8 (-2)
#
# 2,242 UK adults, 29-31 Oct
# (Changes from 22-24 Oct)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 04/11/2021
#
#
# Categories
#
# Politics Public and communities Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,242 UK adults online from 29-31 October 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_Final_29-31 Oct 2021 (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 27th October 2021
# Westminster Voting Intention, fieldwork 22-24 October 2021
#
#
# CON: 37% (-3)
# LAB: 35% (=)
# LDM: 8% (=)
# GRN: 7% (+2)
# SNP: 5% (+1)
# Other 10% (+2)
# 22-24 Oct 2021
# (Changes from 15-17 Sept)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 27/10/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,258 UK adults online from 22-24 October 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 14th October 2021
# Westminster Voting Intention, fieldwork 8-10 October 2021
#
#
# Con 40 (=)
# Lab 35 (=)
# LDM 8 (-1)
# Grn 5 (+1)
# SNP 5 (=)
# Other 7 (-1)
# 8-10 Oct, 2,103 UK adults
# (Changes from 1-3 Oct)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 14/10/2021
#
#
# Categories
#
# Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,103 UK adults online from 8-10 October 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_03_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 15th September 2021
# Westminster Voting Intention
#
#
# Our lowest Con vote share since 12-14 March
#
# Con 39 (-1)
# Lab 35 (-1)
# LDM 9 (=)
# Green 6 (+2)
# SNP 4 (=)
# Other 9 (+1)
#
# 10-12 Sept, 2,097 UK adults
# (Changes from 3-5 Sept)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 15/09/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,097 UK adults online from 10-12 September 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI Post weight_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 19th August 2021
# Westminster Voting Intention
#
#
#
# Con 41 (=)
# Lab 34 (+1)
# LDM 9 (-1)
# GRN 4 (=)
# SNP 4 (=)
# Other 7 (=)
#
# 13-15 Aug, 2,075 UK adults
# (Changes from 6-8 Aug)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 19/08/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,075 UK adults online from 13-15 August 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# MPP_20210819_02_Private (0.49MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 25th August 2021
# Westminster Voting Intention
#
#
#
# Con 41 (=)
# Lab 34 (=)
# LDM 9 (=)
# GRN 4 (=)
# SNP 4 (=)
# Other 7 (=)
#
# 20-22 Aug, 2,083 UK adults
# (Changes from 13-15 Aug)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 25/08/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,083 UK adults online from 20-22 August 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210823_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 2nd September 2021
# Westminster Voting Intention
#
#
# Con 40 (-1)
# Lab 34 (=)
# LDM 10 (+1)
# GRN 5 (+1)
# SNP 4 (=)
# Other 6 (-1)
# 27-29 Aug, 2,062 UK adults
# (Changes from 20-22 Aug)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 02/09/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,062 UK adults online from 27-29 August 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210901_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 12th August 2021
# Westminster Voting Intention (6-8 August 2021)
#
#
#
#
#
#
#
# Con 41 (+1)
# Lab 33 (-1)
# LDM 10 (=)
# GRN 4 (-2)
# SNP 4 (=)
# Other 7 (+2)
#
# 6-8 Aug, 2047 UK adults
# (Changes from 30 Jul - 1 Aug)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 12/08/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,047 UK adults online from 6-8 August 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210811_02_Private (0.13MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 3rd Aug 2021
# Westminster Voting Intention
#
#
# Con 40 (=)
# Lab 34 (=)
# LDM 10 (=)
# GRN 6 (+2)
# SNP 4 (=)
# Other 5 (-2)
# 30 July - 1 August, 2,100 UK adults
# (Changes from 23-25 July)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 03/08/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,100 UK adults online from 30 July - 1 August 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210803_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 28th July 2021
# Westminster Voting Intention - 23-25 July
#
#
# Con 40 (-1)
# Lab 34 (=)
# LDM 10 (+2)
# GRN 4 (-1)
# SNP 4 (=)
# Other 7 (=)
# 23-25 July, 2,161 UK adults
# (Changes from 16-18 July)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 28/07/2021
#
#
# Categories
#
# Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,161 UK adults online from 23-25 July 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210727_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 14 July
# Westminster Voting Intention - 9-11 July
#
#
# Con 40 (-1)
# Lab 35 (=)
# LDM 9 (+1)
# GRN 6 (+2)
# SNP 4 (+1)
# Other 7 (-2)
# 9-11 July, 2,137 UK adults (Changes from 2-4 July)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 14/07/2021
#
#
# Categories
#
# Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,137 UK adults online from 9-11 July 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210712_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 6th July 2021
# Westminster Voting Intention 2-4 July 2021
#
#
#
# Con 41 (-1)
#
#
# Lab 35 (+2)
#
#
# LDM 8 (-1)
#
#
# Grn 4 (-1)
#
#
# SNP 3 (-1)
#
#
# Other 9 (+1)
#
#
#
#
#
# 2-4 July
#
#
#
#
#
# (Changes from 25-27 June)
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 06/07/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,176 UK adults online from 2-4 July 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210705_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 29th June 2021
# Westminster Voting Intention
#
#
#
# Westminster Voting Intention
#
#
#
#
#
# Con 42% (-2)
#
#
# Lab 33% (+3)
#
#
# LDM 9% (-)
#
#
# Grn 5% (=)
#
#
# SNP 4% (=)
#
#
# Other 8% (+2)
#
#
#
#
#
# 25-27 June
#
#
#
#
#
# (Changes from 18-20 June)
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 29/06/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,148 UK adults online from 27-29 June 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210629_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 22nd June 2021
# Westminster Voting Intention
#
#
#
# Con 44 (+3)
# Lab 30 (-4)
# LDM 10 (+2)
# GRN 5 (-1)
# SNP 4 (-1)
# Other 6 (-1)
#
# 18-20 June
# (Changes from 11-13 June)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 22/06/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,191 UK adults online from 18-20 June 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210622_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 9th June 2021
# Westminster Voting Intention
#
#
# The Conservatives have a 12pt lead over Labour
#
# Con 44% (+2)
# Lab 32% (=)
# LDM 8% (-1)
# Green 5% (=)
# SNP 4% (=)
# Other 7% (=)
#
# 4-6 June
# (Changes from 28-30 May)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 09/06/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,089 UK adults online from 4-6 June 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210609_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention and Government pandemic priority polling - 3rd June 2021
# Westminster Voting intention and polling on protecting care homes from coronavirus and whether the government prioritised saving lives or the economy in responding to the pandemic.
#
#
#
# Con 42 (-1)
# Lab 32 (-2)
# LDM 9 (=)
# Green 5 (+1)
# SNP 4 (=)
# Other 7 (-1)
#
# 28-30 May
# (Changes from 21-23 May)
#
#
# Two-thirds (63%) UK adults say the Government did not do enough to protect care homes from coronavirus at the start of the pandemic
# This includes three in five Conservative voters (59%), and almost three-quarters of those aged 55+ (71%)
# Two in five Britons say the Government made a lot of mistakes at the start of the pandemic last March (38%)
# Half say the Government prioritised the economy more than saving lives at the start of the pandemic (48%), compared to a third who said the same of 2021 (33%)
#
# Two-thirds UK adults say that the Government did not do enough (63%) to protect care homes from coronavirus at the start of the pandemic last year. Worryingly for the Conservatives, this includes three in five of their own voters from 2019 (59%), and almost three-quarters of those aged 55+ (71%).
# Elsewhere in the poll, two in five say that the Government ‘made a lot of mistakes’ in how they handled the pandemic last March (38%), while a similar proportion say they ‘made some mistakes’ (43%).
# Just one in eight Britons say the Government ‘did not make many mistakes’ (12%) at the start of the pandemic last March.
# Much has been made about whether government’s, including the UK government, have had to choose between prioritising saving lives and protecting the economy.
# Britons are twice as likely to say that, at the start of the pandemic, the Government prioritised the economy more than saving lives (48%), than saving lives over the economy (26%).
# However, for Britons, by Winter 2020 this had reversed and two in five say the Government prioritised saving lives more than the economy (38%), with a third saying the opposite (32%).
# And, by 2021, a quarter of Britons say that the Government prioritised both saving lives and the economy ‘equally’ (26%), higher than at any other point.
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 03/06/2021
#
#
# Categories
#
# Politics Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,180 UK adults online between 28-30 May. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210603_02_Private (0.11MB)
# InternalPR_20210602_01_Private (0.05MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 27th May 2021
# Westminster Voting Intention
#
#
#
# Con 43 (=)
#
#
# Lab 34 (+2)
#
#
# LDM 9 (+1)
#
#
# Green 4 (-1)
#
#
# SNP 4 (=)
#
#
# Other 8 (=)
#
#
#
#
#
# 21-23 May
#
#
#
#
#
# (Changes from 14-16 May)
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 27/05/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,215 UK adults online from 21st to 23rd May 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210525_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 11th April 2021
# Westminster Voting Intention
#
#
#
#
# Con 42 (+2)
# Lab 34 (-2)
# LDM 8 (=)
# Green 4 (=)
# SNP 5 (+1)
# Other 8 (+1)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 11/05/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,242 UK adults aged 18+ online between 30th April and 2nd May 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210504 02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 28th April 2021
# Westminster Voting Intention
#
#
# Conservative lead narrows, but still a 7pt gap.
# Westminster Voting Intention: Con 42 (-1) Lab 35 (+1) LDM 8 (+1) SNP 5 (=) Green 3 (-1) Other 7 (=)
# 23-25 April
# Changes from 16-18 April
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 28/04/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,144 UK adults aged 18+ online between 16th and 18th April 2021. Data were weighted by age, sex, region and social grade. Voting intention was also weighted by 2019 and 2016 past vote, and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210427_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 14th April 2021
# Westminster Voting Intention and polling around the timing of lockdown restrictions lifting.
#
#
#
# A quarter of 18-34-year-olds say restrictions are lifting ‘too slowly’ (24%), with around two in five of the same age group saying the timing is ‘about right’ (43%)
# Younger adults (18-34) are also the least likely to say that current restrictions are clear (49%), compared to two in five of those aged 35-54 (21%), and 14% of 55+
# Westminster Voting Intention: Con 42% (=), Lab 35% (=), LDM 7% (-1), SNP 5% (+1), Green 4% (+1), Other 7% (=) – changes from 2-4 April
#
# COVID restrictions and vaccine rollout
# Overall amongst UK adults, half (50%) say that the timing of the UK coming out of lockdown is ‘about right’, with a quarter saying its too fast (26%) and two in five saying that its too slow (19%).
# The proportion who say its too slow rises to a quarter (24%) amongst those aged 18-34, with two in five of this age group (43%) saying that the timing is ‘about right’.
# Unsurprisingly, over three in five 2019 Conservative voters say that the government’s roadmap is ‘about right’ (63%), while a third of Labour voters say that its ‘too fast’ (33%).
# Are the current restrictions clear?
# Overall, it seems that UK adults think that they are. Three in five (61%) say that they are clear, with under one in five saying that they are unclear (17%). Those aged 18-34 are the most likely to say that the restrictions are ‘unclear’ (21%).
# New variants a threat to the roadmap?
# Despite the success of the vaccine rollout and both cases and deaths at their lowest for months, three in five are ‘concerned’ that new variants of coronavirus could push back the UK’s roadmap out of lockdown (61%), with a third saying that they are ‘not concerned’ about this (33%).
# Those aged 55+ (68%) and 2019 Labour voters (69%) are the most concerned groups, while those aged 18-34 are the most likely to say that they are not concerned (37%).
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 14/04/2021
#
#
# Categories
#
# Politics Public and communities Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,174 UK adults aged 18+ online between 9th-11th April 2021 . Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# Topical_20210412_Private (0.08MB)
# VI_20210413_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention
#
#
#
# Con 42% (=)
# Lab 35% (-3)
# LD 8% (+2)
# Green 3% (=)
# SNP 4% (=)
# Other 7% (=)
# 2-4 April
# (Changes from 19-21 March)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 6/4/2021
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,065 UK adults online between 2-4 April 2021. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_Tables_20210406_02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 26th March 2021
# Westminster Voting Intention
#
#
#
#
# Con 42% (+3)
# Lab 38% (+1)
# LD 6% (-2)
# Green 3% (-1)
# SNP 4% (=)
# Other 7% (-1)
# 19-21 March
# (Changes from 12-14 March)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 26/03/2020
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,098 UK adults online between 19th-21st March 2021. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
# VI_20210325_03_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 10th March 2021
# Savanta ComRes Westminster Voting Intention
#
#
#
# Westminster Voting Intention: Con 42% (-1), Lab 36% (=), Lib Dem 8% (+1), SNP 4% (=), Green 4% (+1), Other 8% (+)
#
# The latest Westminster Voting Intention from Savanta ComRes sees the Conservatives on 42% of the vote share, 6pts up on Labour who have 36%. The figure for the Conservatives is 1pt down from last week, while Labour’s vote share is unchanged. The Liberal Democrats see a 1pt rise on last week's voting intention and have 8% of the vote share.
# Amongst 2016 ‘Leave’ voters, two thirds (64%) would now vote for the Conservatives, while one in five would vote for Labour (19%). Amongst ‘Remain’ voters, a quarter would vote for the Conservatives (24%), with just under half saying they would vote for Labour (47%).
#
#
#
#
# Leavers
# Remainers
# Men
# Women
# 55+
# 35-54
#
#
# Con
# 64%
# 24%
# 45%
# 38%
# 55%
# 33%
#
#
# Lab
# 19%
# 47%
# 33%
# 39%
# 25%
# 41%
#
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 10/03/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 1,285 UK adults aged 18+ online between 5th-7th March 2021. Data were weighted to be representative of all UK adults by age, sex, region and SEG. Savanta ComRes is a member of the British Polling Council and abides by its rules
#
#
#
# VI_20210309 02_Private (0.11MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 2nd March 2021
# Westminster Voting Intention
#
#
#
# Con 43 (+3)
# Lab 36 (-2)
# LD 7 (=)
# SNP 4 (=)
# Green 3 (=)
# Other 7 (=)
#
# 26-28 Feb
# (changes from 19-21 Feb)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 02/03/2021
#
#
# Categories
#
# Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,182 UK adults aged 18+ online between 26th and 28th February 2021. Data were weighted to be representative of all UK adults by age, sex, region and SEG. Voting intention was also weighted by likelihood to vote, and past vote recall from the 2019 General Election and 2016 EU Referendum. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
#  (1.23MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 24th Feb
# Westminster voting intention
#
#
# Westminster Voting Intention: Con 40 (-2), Lab 38 (+1), Lib Dem 7 (-), SNP 4 (-), Green 3 (-) – changes from 12th-14th Feb
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 24/02/2021
#
#
# Categories
#
# Public and communities Voting Intention
#
#
# Client
# Savanta ComRes
#
#
# Methodology
# Savanta ComRes interviewed 2,189 UK adults aged 18+ online between 19th and 22nd February 2021. Data were weighted to be representative of all UK adults by age, sex, region and SEG. Voting intention was also weighted by likelihood to vote, and past vote recall from the 2019 General Election and 2016 EU Referendum. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
#  (0.4MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster voting intention - 11 Feb
# Poll of UK adults on their voting intentions.
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 11/02/2021
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,119 UK adults online from the 5 to 7 February 2021. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules
#
#
#
#  (0.4MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster voting intention - 3 Feb
# Poll of UK adults on their voting intentions.
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 03/02/2021
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,288 UK adults online from the 29 to 31 January 2021. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
#  (0.39MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 29 Jan
# Poll of UK adults on their voting intentions.
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 29/01/2021
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,070 UK adults online from the 22 to 24 January 2021. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
#  (0.4MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 22 Jan
# Poll of UK adults on their voting intentions
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 22/01/2020
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 1,914 UK adults online from the 15 to 17 January 2021. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
#  (2.08MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 12 Jan
# Poll of UK adults on their voting intentions
#
#
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 12/01/2021
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,302 UK adults online from the 8 to 10 January 2021. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules
#
#
#
#  (0.4MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - Daily Express, 1 Jan
# Poll of UK adults on their voting intention, aspirations for 2021 and attitudes towards Brexit.
#
#
# Con - 41%
# Lab - 39%
# LD - 8%
# SNP - 5%
# Green - 4%
# Other - 4%
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 01/01/2021
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Client
# Daily Express
#
#
# Methodology
# Savanta ComRes interviewed 2,211 UK adults online from the 18 to 21 December 2020. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
#  (0.7MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 2 December
# Poll of UK adults on their Westminster voting intentions.
#
#
#
#
# Headline Westminster Voting Intention:
# Con 39 (-)
# Lab 38 (+1)
# LD 8 (+1)
# SNP 5 (-)
# Green 3 (-1)
# Other 7 (-1)
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 2/12/20
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,178 UK adults online from the 27 to 29 November 2020. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote. Savanta ComRes is a member of the British Polling Council and abides by its rules.
#
#
#
#  (1.88MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY
#
#
#
#
#
# Westminster Voting Intention - 14th Oct
# Poll of UK adults on their voting intentions.
#
#
# Lab 39%
# Con 39%
# LD 7%
# Other 15%
#
# CONTACT US TO FIND OUT MORE ABOUT HOW WE CAN HELP YOU
#
#
#
# Date Published
# 14/10/2020
#
#
# Categories
#
# Politics UK Voting Intention
#
#
# Methodology
# Savanta ComRes interviewed 2,123 UK adults online from the 9 to 14 October 2020. Data were weighted to be demographically representative of all UK adults. Voting Intention is also weighted by 2019 past vote recall, EU Referendum past vote and likelihood to vote.
#
#
#
#  (0.4MB)
# .sharify-title {display:none} .sharify-count{display:none} .sharify-container li {display:inline-block}
#
# SHARE THIS STORY

# %%
# Creating a variable a to store the length of the array 'Polls'

a = len(Polls)


# Extracting polling data for the conservative party 

count = 0
found = False

# Creating two arrays, the first stores the polling value and the second stores the date the poll was published 

Conservative_poll_values = []
Conservative_poll_dates = []

# For loop, loops through the text data, looking for a match for 'Con' and stores the value of the polling data in the array 'Conservative_poll_values'

# Additionally, looks for a match with 'Date Published' and stores the date in the array 'Conservative_poll_dates' 

for i in range(0,a):
  b=len(Polls[i])
  found = False
  for j in range(0,b):
    if((Polls[i][j] =='C' and Polls[i][j+1] == 'o'and Polls[i][j+2] == 'n' and Polls[i][j+3] == ' ' and Polls[i][j+4] != 'v') or (Polls[i][j] =='C' and Polls[i][j+1] == 'O'and Polls[i][j+2] == 'N' and Polls[i][j+3] != 'T')):
      print(Polls[i][j+4:j+8])
      Conservative_poll_values.append(Polls[i][j+4:j+8])
      count = count + 1
      found = True

    if((found == True) and (Polls[i][j:j+14] == 'Date Published')):
      Conservative_poll_dates.append(Polls[i][j+15:j+25])
# Out:
# 34 (
# 40 (
# 38 (
# 34 (
#  38%
# 40 (
#  37%
# 40 (
# 39 (
# 41 (
# 41 (
# 40 (
# 41 (
# 40 (
# 40 (
# 40 (
# 41 (
# 42%
# 44 (
# 44%
# 42 (
# 43 (
# 42 (
# 42 (
# 42%
# 42%
# 42%
# 42%
# 43 (
# 40 (
# - 41
# 39 (
# 39%

# %%
# Inputting the scraped polling data into a table and cleaning

# Creating a data frame to store Conservative poll data

df1 = pd.DataFrame([Conservative_poll_values,Conservative_poll_dates]).T
df1.columns = ['Conservative Poll','Date']

# Cleaning the data

df1['Conservative Poll'] = df1['Conservative Poll'].str.replace('(',' ')
df1['Conservative Poll'] = df1['Conservative Poll'].str.replace('%',' ')
df1['Conservative Poll'] = df1['Conservative Poll'].str.replace('\n',' ')
df1['Conservative Poll'] = df1['Conservative Poll'].str.replace('-',' ')
df1['Date'] = df1['Date'].str.replace('\n',' ')


df1
# Out:
#    Conservative Poll        Date
# 0               34    17/12/2021
# 1               40    6/10/2021
# 2               38    07/12/2021
# 3               34    12/11/2021
# 4                38   09/11/2021
# 5               40    04/11/2021
# 6                37   27/10/2021
# 7               40    14/10/2021
# 8               39    15/09/2021
# 9               41    19/08/2021
# 10              41    25/08/2021
# 11              40    02/09/2021
# 12              41    12/08/2021
# 13              40    03/08/2021
# 14              40    28/07/2021
# 15              40    14/07/2021
# 16              41    06/07/2021
# 17              42    29/06/2021
# 18              44    22/06/2021
# 19              44    09/06/2021
# 20              42    03/06/2021
# 21              43    27/05/2021
# 22              42    11/05/2021
# 23              42    28/04/2021
# 24              42    14/04/2021
# 25              42    6/4/2021
# 26              42    26/03/2020
# 27              42    10/03/2021
# 28              43    02/03/2021
# 29              40    24/02/2021
# 30                41  01/01/2021
# 31              39    2/12/20
# 32              39    14/10/2020

# %%
# Creating monthly averages for consevative polling data

df1["Date"] = pd.to_datetime(df1["Date"])

df1['Conservative Poll'] = pd.to_numeric(df1['Conservative Poll'], errors ='coerce')

DF_Conservative_Approval_Monthly = df1.resample('M', on='Date').mean().reset_index()

DF_Conservative_Approval_Monthly['Date'] = pd.DatetimeIndex(DF_Conservative_Approval_Monthly['Date']) + pd.DateOffset(1)

DF_Conservative_Approval_Monthly
# Out:
#          Date  Conservative Poll
# 0  2020-03-01          39.000000
# 1  2020-04-01          42.000000
# 2  2020-05-01                NaN
# 3  2020-06-01                NaN
# 4  2020-07-01                NaN
# 5  2020-08-01                NaN
# 6  2020-09-01                NaN
# 7  2020-10-01                NaN
# 8  2020-11-01          39.000000
# 9  2020-12-01                NaN
# 10 2021-01-01                NaN
# 11 2021-02-01          41.000000
# 12 2021-03-01          41.000000
# 13 2021-04-01          41.000000
# 14 2021-05-01          41.333333
# 15 2021-06-01          43.000000
# 16 2021-07-01          41.800000
# 17 2021-08-01          39.333333
# 18 2021-09-01          41.000000
# 19 2021-10-01          40.333333
# 20 2021-11-01          39.666667
# 21 2021-12-01          42.000000
# 22 2022-01-01          36.333333

# %%
# Downloading the 'CPIH INDEX: Liquid fuels, vehicle fuels & lubricants' dataset from the Office for National Statistics API in JSON format 

url = 'https://api.ons.gov.uk/timeseries/L5JL/dataset/MM23/data'
html = requests.get(url)
ONS_Fuel_Index_Data = html.json()
Months = ONS_Fuel_Index_Data['months']

# %%
# Appending the observations from the date and value categories in the JSON file and storing them in a dataframe. 

ONS_ARRAY=[]
for month in Months:
  temp_variable={'date':month['date'],'value':month['value']}
  ONS_ARRAY.append(temp_variable)

DF_FUEL_INDEX=pd.DataFrame(ONS_ARRAY)

DF_FUEL_INDEX["date"] = pd.to_datetime(DF_FUEL_INDEX["date"])

DF_FUEL_INDEX.columns = ['Date','CPIH INDEX: Liquid fuels, vehicle fuels & lubricants (G) 2015=100']

DF_FUEL_INDEX['CPIH INDEX: Liquid fuels, vehicle fuels & lubricants (G) 2015=100'] = pd.to_numeric(DF_FUEL_INDEX['CPIH INDEX: Liquid fuels, vehicle fuels & lubricants (G) 2015=100'], errors ='coerce')

DF_FUEL_INDEX
# Out:
#           Date  CPIH INDEX: Liquid fuels, vehicle fuels & lubricants (G) 2015=100
# 0   1988-01-01                                               30.4
# 1   1988-02-01                                               30.0
# 2   1988-03-01                                               29.9
# 3   1988-04-01                                               30.5
# 4   1988-05-01                                               30.5
# ..         ...                                                ...
# 402 2021-07-01                                              119.6
# 403 2021-08-01                                              121.1
# 404 2021-09-01                                              121.6
# 405 2021-10-01                                              126.2
# 406 2021-11-01                                              132.6
#
# [407 rows x 2 columns]

# %%
# Merging the data from the two data sources to create a single data set 

DF_Conservative_Approval_Monthly_With_Fuel_Index = DF_Conservative_Approval_Monthly.merge(DF_FUEL_INDEX, left_on='Date', right_on='Date')

DF_Conservative_Approval_Monthly_With_Fuel_Index.dropna(subset = ["Conservative Poll"], inplace=True)

# Filtering for 2021

DF_Conservative_Approval_Monthly_With_Fuel_Index = DF_Conservative_Approval_Monthly_With_Fuel_Index[(DF_Conservative_Approval_Monthly_With_Fuel_Index['Date'].dt.year > 2020)]

DF_Conservative_Approval_Monthly_With_Fuel_Index
# Out:
#          Date  ...  CPIH INDEX: Liquid fuels, vehicle fuels & lubricants (G) 2015=100
# 11 2021-02-01  ...                                              109.2
# 12 2021-03-01  ...                                              112.3
# 13 2021-04-01  ...                                              113.4
# 14 2021-05-01  ...                                              115.1
# 15 2021-06-01  ...                                              117.4
# 16 2021-07-01  ...                                              119.6
# 17 2021-08-01  ...                                              121.1
# 18 2021-09-01  ...                                              121.6
# 19 2021-10-01  ...                                              126.2
# 20 2021-11-01  ...                                              132.6
#
# [10 rows x 3 columns]

# %%
# Creating a month field

DF_Conservative_Approval_Monthly_With_Fuel_Index['Month'] = pd.DatetimeIndex(DF_Conservative_Approval_Monthly_With_Fuel_Index['Date']).month

# Exporting the data to csv

DF_Conservative_Approval_Monthly_With_Fuel_Index.to_csv("Project_Conservative_Approval_Monthly_With_Fuel_Index.csv")
